# %%
import pandas as pd
import matplotlib.pyplot as plt

netflix_df= pd.read_csv("netflix_data.csv")
netflix_df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
filtered_1 = netflix_df[netflix_df["release_year"]>= 1990]
filtered_1.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
filter_2 = filtered_1[filtered_1["release_year"] <2000]
filter_2.head()
# Out:
#     show_id   type                            title            director  \
# 7        s8  Movie                              187      Kevin Reynolds
# 166    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 210    s211  Movie           A Night at the Roxbury    John Fortenberry
# 238    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 273    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 166  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 210  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 238  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 273  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 7    November 1, 2019          1997       119
# ...

# %%
nintees_movies = filter_2[filter_2["type"] == "Movie"]
nintees_movies.head()
# Out:
#     show_id   type                            title            director  \
# 7        s8  Movie                              187      Kevin Reynolds
# 166    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 210    s211  Movie           A Night at the Roxbury    John Fortenberry
# 238    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 273    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 166  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 210  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 238  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 273  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 7    November 1, 2019          1997       119
# ...

# %%
#number of movies released in 90s era.
plt.figure(figsize=(10, 6))
nintees_movies['release_year'].value_counts().sort_index().plot(kind='bar')
plt.title('Number of Movies Released Each Year in the 1990s')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.show()

# %%
most_frequent_duration = nintees_movies['duration'].mode().iloc[0]
most_frequent_duration

print(f"The most frequent duration of movies in 1990s is {most_frequent_duration} minutes.")
# Out:
# The most frequent duration of movies in 1990s is 94 minutes.

# %%
plt.figure(figsize=(10,6))
plt.hist(nintees_movies["duration"],bins=10, edgecolor = "black")
plt.title("distribution of movies in 90s")
plt.xlabel("duration(minutes)")
plt.ylabel("number of movies")
plt.show()

# %%
#short action movies
short_movies = nintees_movies[nintees_movies["duration"]<= 90]

short_movies.head()
# Out:
#     show_id   type                                              title  \
# 210    s211  Movie                             A Night at the Roxbury
# 486    s487  Movie                 An American Tail: Fievel Goes West
# 487    s488  Movie  An American Tail: The Mystery of the Night Mon...
# 623    s624  Movie                  Auschwitz: Blueprints of Genocide
# 626    s627  Movie        Austin Powers: International Man of Mystery
#
#                         director  \
# 210             John Fortenberry
# 486  Phil Nibbelink, Simon Wells
# 487                 Larry Latham
# 623                Mike Rossiter
# 626                    Jay Roach
#
#                                                   cast         country  \
# 210  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...   United States
# 486  Philip Glasser, James Stewart, Erica Yohn, Cat...   United States
# 487  Thomas Dekker, Lacey Chabert, Jane Singer, Neh...   United States
# ...

# %%
short_action_movies_count = short_movies[short_movies["genre"] == "Action"]
print(short_action_movies_count.value_counts('genre'))
# Out:
# genre
# Action    8
# Name: count, dtype: int64

# %%
#Part 2
#To determine whether the average duration of movies on Netflix has been declining over the years.
netflix_movie_only = netflix_df[netflix_data["type"]== "Movie"]
netflix_movie_only.head()
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
# 6       June 1, 2020          2019        95
#
# ...

# %%
duration_movie = netflix_movie_only[["title","type","genre","release_year","duration"]]
duration_movie.head()
# Out:
#    title   type          genre  release_year  duration
# 1   7:19  Movie         Dramas          2016        93
# 2  23:59  Movie  Horror Movies          2011        78
# 3      9  Movie         Action          2009        80
# 4     21  Movie         Dramas          2008       123
# 6    122  Movie  Horror Movies          2019        95

# %%
#Calculating the total average duration.
average_duration_movie = duration_movie[["duration"]].mean()
average_duration_movie
# Out:
# duration    99.307978
# dtype: float64

# %%
#average durartion in 90s
average_duration_movies_90s = nintees_movies[["duration"]].mean()
print(f"average duration of movies in 90s is : {average_duration_movies_90s} minutes")
# Out:
# average duration of movies in 90s is : duration    113.917526
# dtype: float64 minutes

# %%
#averge duration of movies from 2000 to latest .
movies_2000s= duration_movie[duration_movie["release_year"]>=2000]
movies_2000s_filtered = movies_2000s[movies_2000s["release_year"]< 2010]
movies_2000s_filtered.head()
# Out:
#           title   type          genre  release_year  duration
# 3             9  Movie         Action          2009        80
# 4            21  Movie         Dramas          2008       123
# 9          1920  Movie  Horror Movies          2008       143
# 44     Æon Flux  Movie         Action          2005        93
# 50  10,000 B.C.  Movie         Action          2008       109

# %%
average_2000s_duration = movies_2000s_filtered[["duration"]].mean()
print(f"The average duration of movies in 2000s is :{average_2000s_duration} minutes")
# Out:
# The average duration of movies in 2000s is :duration    112.637271
# dtype: float64 minutes

# %%
#overall average duration in scatter figure.
plt.figure(figsize=(8, 6))
plt.scatter(duration_movie['release_year'],duration_movie['duration'], color='green')
plt.title('Duration of movie')
plt.xlabel('released year')
plt.ylabel("duration")
plt.grid(True)
plt.show()

# %%
# average duration of movies from 2010 to 2020.
movies_latest = duration_movie[duration_movie["release_year"]>2010]
movies_latest.head()
# Out:
#     title   type          genre  release_year  duration
# 1    7:19  Movie         Dramas          2016        93
# 2   23:59  Movie  Horror Movies          2011        78
# 6     122  Movie  Horror Movies          2019        95
# 8     706  Movie  Horror Movies          2019       118
# 10   1922  Movie         Dramas          2017       103

# %%
average_duration_latest = movies_latest[["duration"]].mean()
print(f"The average duration of movies from 2010 to 2020 is:{average_duration_latest} minutes")
# Out:
# The average duration of movies from 2010 to 2020 is:duration    95.793535
# dtype: float64 minutes

# %%
import numpy as np
durations = np.array([ 113.91, 112.63, 95.79])
movies = ["average_duration_movies_90s" , "average_2000s_duration", "average_duration_latest"]
plt.pie(durations, labels = movies, autopct='%1.1f%%')
plt.title("Average movies duration from 1990s to 2020")

plt.show()

# %%
# Answer = The duration of movies has been decreased by around 6 percentage or by 13 minutes through out the time period from 1990s to 2020.

plt.figure(figsize=(8, 6))
plt.scatter(average_duration_movies_90s['duration'],average_duration_latest ['duration'], color='blue')
plt.xlabel("90s")
plt.ylabel("modern")
plt.title("comaparing 90s")
plt.show()

# %%
import numpy as py
x = np.array([95.79,112.16, 113.91])
y = ["average_duration_latest","average_2000s_duration","average_duration_movies_90s"]
plt.plot(x,y)
plt.show()

# %%
# Trend analysis
netflix_df['release_year'] = pd.to_datetime(netflix_df['release_year'], format='%Y')
#Grouping by the year and counting the number of releases.
yearly_releases = netflix_df.groupby(netflix_df["release_year"].dt.year).size()
plt.figure(figsize=(10, 5))
yearly_releases.plot(kind='line')
plt.title('Number of Netflix Releases Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.show()

# %%
#Genre analysis.


genre_count = netflix_df[["genre"]].value_counts()
genre_count.head()
# Out:
# genre
# Dramas              1384
# Comedies            1074
# Documentaries        751
# Action               721
# International TV     690
# Name: count, dtype: int64

# %%
# Plot the genre distribution
plt.figure(figsize=(12, 6))
genre_count.plot(kind='bar')
plt.title('Distribution of Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.show()

# %%
# genre such as drama and comedies seems to have most impact on netflix as a means of entertainment followed by documentaries and actions.
